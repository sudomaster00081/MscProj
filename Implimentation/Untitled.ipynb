# %%
import numpy as np
import pandas as pd
from minisom import MiniSom
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score

# Load the dataset
data = pd.read_csv("labeled_ddostrace.to-victim.20070804.csv")

# Convert other columns to appropriate data types
data['Source IP'] = data['Source IP'].astype(str)
data['Destination IP'] = data['Destination IP'].astype(str)
data['Protocol'] = pd.to_numeric(data['Protocol'], errors='coerce') # if it's numeric
data['Frame Length'] = pd.to_numeric(data['Frame Length'], errors='coerce') # if it's numeric
data['Port Used'] = pd.to_numeric(data['Port Used'], errors='coerce') # if it's numeric
data['Interpacket Time'] = pd.to_numeric(data['Interpacket Time'], errors='coerce') # if it's numeric
data['Entropy'] = pd.to_numeric(data['Entropy'], errors='coerce') # if it's numeric
data['label'] = pd.to_numeric(data['label'], errors='coerce') # if it's numeric

# Drop rows with missing values
data.dropna(inplace=True)

# Separate features and labels
X = data.drop(['label', 'Timestamp', 'Source IP', 'Destination IP'], axis=1).values
y = data['label'].values
print(y)
# Normalize features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Define SOM parameters
som_grid_rows = 10
som_grid_columns = 10
input_len = X_scaled.shape[1]
num_iterations = 10000

# Train SOM
som = MiniSom(som_grid_rows, som_grid_columns, input_len, sigma=1.0, learning_rate=0.5)
som.random_weights_init(X_scaled)
som.train_batch(X_scaled, num_iterations)

# Find the winning neurons for each sample
winning_neurons = np.array([som.winner(x) for x in X_scaled])

# Assign labels to clusters based on the majority label of the samples in each cluster
cluster_labels = []
total_samples = len(winning_neurons)

for i, neuron in enumerate(winning_neurons):
    cluster_samples_indices = np.where((winning_neurons[:, 0] == neuron[0]) & (winning_neurons[:, 1] == neuron[1]))[0]
    cluster_labels.append(y[cluster_samples_indices].mean())

    # Print progress
    if (i + 1) % 1000 == 0 or i + 1 == total_samples:
        percent_complete = (i + 1) / total_samples * 100
        print(f"Assigning cluster labels: {percent_complete:.2f}% complete")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20712\4155266547.py:8: DtypeWarning: Columns (0,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("labeled_ddostrace.to-victim.20070804.csv")
# [0 1 0 ... 1 0 1]
# Assigning cluster labels: 0.09% complete
# Assigning cluster labels: 0.18% complete
# Assigning cluster labels: 0.26% complete
# Assigning cluster labels: 0.35% complete
# Assigning cluster labels: 0.44% complete
# Assigning cluster labels: 0.53% complete
# Assigning cluster labels: 0.62% complete
# Assigning cluster labels: 0.71% complete
# Assigning cluster labels: 0.79% complete
# Assigning cluster labels: 0.88% complete
# Assigning cluster labels: 0.97% complete
# Assigning cluster labels: 1.06% complete
# Assigning cluster labels: 1.15% complete
# Assigning cluster labels: 1.23% complete
# Assigning cluster labels: 1.32% complete
# Assigning cluster labels: 1.41% complete
# Assigning cluster labels: 1.50% complete
# Assigning cluster labels: 1.59% complete
# Assigning cluster labels: 1.67% complete
# Assigning cluster labels: 1.76% complete
# Assigning cluster labels: 1.85% complete
# Assigning cluster labels: 1.94% complete
# Assigning cluster labels: 2.03% complete
# Assigning cluster labels: 2.12% complete
# Assigning cluster labels: 2.20% complete
# Assigning cluster labels: 2.29% complete
# Assigning cluster labels: 2.38% complete
# Assigning cluster labels: 2.47% complete
# Assigning cluster labels: 2.56% complete
# Assigning cluster labels: 2.64% complete
# Assigning cluster labels: 2.73% complete
# Assigning cluster labels: 2.82% complete
# Assigning cluster labels: 2.91% complete
# Assigning cluster labels: 3.00% complete
# Assigning cluster labels: 3.08% complete
# Assigning cluster labels: 3.17% complete
# Assigning cluster labels: 3.26% complete
# Assigning cluster labels: 3.35% complete
# Assigning cluster labels: 3.44% complete
# Assigning cluster labels: 3.53% complete
# Assigning cluster labels: 3.61% complete
# Assigning cluster labels: 3.70% complete
# Assigning cluster labels: 3.79% complete
# Assigning cluster labels: 3.88% complete
# Assigning cluster labels: 3.97% complete
# Assigning cluster labels: 4.05% complete
# Assigning cluster labels: 4.14% complete
# Assigning cluster labels: 4.23% complete
# Assigning cluster labels: 4.32% complete
# Assigning cluster labels: 4.41% complete
# Assigning cluster labels: 4.50% complete
# Assigning cluster labels: 4.58% complete
# Assigning cluster labels: 4.67% complete
# Assigning cluster labels: 4.76% complete
# Assigning cluster labels: 4.85% complete
# Assigning cluster labels: 4.94% complete
# Assigning cluster labels: 5.02% complete
# Assigning cluster labels: 5.11% complete
# Assigning cluster labels: 5.20% complete
# Assigning cluster labels: 5.29% complete
# Assigning cluster labels: 5.38% complete
# Assigning cluster labels: 5.46% complete
# Assigning cluster labels: 5.55% complete
# Assigning cluster labels: 5.64% complete
# Assigning cluster labels: 5.73% complete
# Assigning cluster labels: 5.82% complete
# Assigning cluster labels: 5.91% complete
# Assigning cluster labels: 5.99% complete
# Assigning cluster labels: 6.08% complete
# Assigning cluster labels: 6.17% complete
# Assigning cluster labels: 6.26% complete
# Assigning cluster labels: 6.35% complete
# Assigning cluster labels: 6.43% complete
# Assigning cluster labels: 6.52% complete
# Assigning cluster labels: 6.61% complete
# Assigning cluster labels: 6.70% complete
# Assigning cluster labels: 6.79% complete
# Assigning cluster labels: 6.87% complete
# Assigning cluster labels: 6.96% complete
# Assigning cluster labels: 7.05% complete
# Assigning cluster labels: 7.14% complete
# Assigning cluster labels: 7.23% complete
# Assigning cluster labels: 7.32% complete
# Assigning cluster labels: 7.40% complete
# Assigning cluster labels: 7.49% complete
# Assigning cluster labels: 7.58% complete
# Assigning cluster labels: 7.67% complete
# Assigning cluster labels: 7.76% complete
# Assigning cluster labels: 7.84% complete
# Assigning cluster labels: 7.93% complete
# Assigning cluster labels: 8.02% complete
# Assigning cluster labels: 8.11% complete
# Assigning cluster labels: 8.20% complete
# Assigning cluster labels: 8.29% complete
# Assigning cluster labels: 8.37% complete
# Assigning cluster labels: 8.46% complete
# Assigning cluster labels: 8.55% complete
# Assigning cluster labels: 8.64% complete
# Assigning cluster labels: 8.73% complete
# Assigning cluster labels: 8.81% complete
# Assigning cluster labels: 8.90% complete
# Assigning cluster labels: 8.99% complete
# Assigning cluster labels: 9.08% complete
# Assigning cluster labels: 9.17% complete
# Assigning cluster labels: 9.25% complete
# Assigning cluster labels: 9.34% complete
# Assigning cluster labels: 9.43% complete
# Assigning cluster labels: 9.52% complete
# Assigning cluster labels: 9.61% complete
# Assigning cluster labels: 9.70% complete
# Assigning cluster labels: 9.78% complete
# Assigning cluster labels: 9.87% complete
# Assigning cluster labels: 9.96% complete
# Assigning cluster labels: 10.05% complete
# Assigning cluster labels: 10.14% complete
# Assigning cluster labels: 10.22% complete
# Assigning cluster labels: 10.31% complete
# Assigning cluster labels: 10.40% complete
# Assigning cluster labels: 10.49% complete
# Assigning cluster labels: 10.58% complete
# Assigning cluster labels: 10.67% complete
# Assigning cluster labels: 10.75% complete
# Assigning cluster labels: 10.84% complete
# Assigning cluster labels: 10.93% complete
# Assigning cluster labels: 11.02% complete
# Assigning cluster labels: 11.11% complete
# Assigning cluster labels: 11.19% complete
# Assigning cluster labels: 11.28% complete
# Assigning cluster labels: 11.37% complete
# Assigning cluster labels: 11.46% complete
# Assigning cluster labels: 11.55% complete
# Assigning cluster labels: 11.63% complete
# Assigning cluster labels: 11.72% complete
# Assigning cluster labels: 11.81% complete
# Assigning cluster labels: 11.90% complete
# Assigning cluster labels: 11.99% complete
# Assigning cluster labels: 12.08% complete
# Assigning cluster labels: 12.16% complete
# Assigning cluster labels: 12.25% complete
# Assigning cluster labels: 12.34% complete
# Assigning cluster labels: 12.43% complete
# Assigning cluster labels: 12.52% complete
# Assigning cluster labels: 12.60% complete
# Assigning cluster labels: 12.69% complete
# Assigning cluster labels: 12.78% complete
# Assigning cluster labels: 12.87% complete
# Assigning cluster labels: 12.96% complete
# Assigning cluster labels: 13.04% complete
# Assigning cluster labels: 13.13% complete
# Assigning cluster labels: 13.22% complete
# Assigning cluster labels: 13.31% complete
# Assigning cluster labels: 13.40% complete
# Assigning cluster labels: 13.49% complete
# Assigning cluster labels: 13.57% complete
# Assigning cluster labels: 13.66% complete
# Assigning cluster labels: 13.75% complete
# Assigning cluster labels: 13.84% complete
# Assigning cluster labels: 13.93% complete
# Assigning cluster labels: 14.01% complete
# Assigning cluster labels: 14.10% complete
# Assigning cluster labels: 14.19% complete
# Assigning cluster labels: 14.28% complete
# Assigning cluster labels: 14.37% complete
# Assigning cluster labels: 14.46% complete
# Assigning cluster labels: 14.54% complete
# Assigning cluster labels: 14.63% complete
# Assigning cluster labels: 14.72% complete
# Assigning cluster labels: 14.81% complete
# Assigning cluster labels: 14.90% complete
# Assigning cluster labels: 14.98% complete
# Assigning cluster labels: 15.07% complete
# Assigning cluster labels: 15.16% complete
# Assigning cluster labels: 15.25% complete
# Assigning cluster labels: 15.34% complete
# Assigning cluster labels: 15.42% complete
# Assigning cluster labels: 15.51% complete
# Assigning cluster labels: 15.60% complete
# Assigning cluster labels: 15.69% complete
# Assigning cluster labels: 15.78% complete
# Assigning cluster labels: 15.87% complete
# Assigning cluster labels: 15.95% complete
# Assigning cluster labels: 16.04% complete
# Assigning cluster labels: 16.13% complete
# Assigning cluster labels: 16.22% complete
# Assigning cluster labels: 16.31% complete
# Assigning cluster labels: 16.39% complete
# Assigning cluster labels: 16.48% complete
# Assigning cluster labels: 16.57% complete
# Assigning cluster labels: 16.66% complete
# Assigning cluster labels: 16.75% complete
# Assigning cluster labels: 16.83% complete
# Assigning cluster labels: 16.92% complete
# Assigning cluster labels: 17.01% complete
# Assigning cluster labels: 17.10% complete
# Assigning cluster labels: 17.19% complete
# Assigning cluster labels: 17.28% complete
# Assigning cluster labels: 17.36% complete
# Assigning cluster labels: 17.45% complete
# Assigning cluster labels: 17.54% complete
# Assigning cluster labels: 17.63% complete
# Assigning cluster labels: 17.72% complete
# Assigning cluster labels: 17.80% complete
# Assigning cluster labels: 17.89% complete
# Assigning cluster labels: 17.98% complete
# Assigning cluster labels: 18.07% complete
# Assigning cluster labels: 18.16% complete
# Assigning cluster labels: 18.25% complete
# Assigning cluster labels: 18.33% complete
# Assigning cluster labels: 18.42% complete
# Assigning cluster labels: 18.51% complete
# Assigning cluster labels: 18.60% complete
# Assigning cluster labels: 18.69% complete
# Assigning cluster labels: 18.77% complete
# Assigning cluster labels: 18.86% complete
# Assigning cluster labels: 18.95% complete
# Assigning cluster labels: 19.04% complete
# Assigning cluster labels: 19.13% complete
# Assigning cluster labels: 19.21% complete
# Assigning cluster labels: 19.30% complete
# Assigning cluster labels: 19.39% complete
# Assigning cluster labels: 19.48% complete
# Assigning cluster labels: 19.57% complete
# Assigning cluster labels: 19.66% complete
# Assigning cluster labels: 19.74% complete
# Assigning cluster labels: 19.83% complete
# Assigning cluster labels: 19.92% complete
# Assigning cluster labels: 20.01% complete
# Assigning cluster labels: 20.10% complete
# Assigning cluster labels: 20.18% complete
# Assigning cluster labels: 20.27% complete
# Assigning cluster labels: 20.36% complete
# Assigning cluster labels: 20.45% complete
# Assigning cluster labels: 20.54% complete
# Assigning cluster labels: 20.62% complete
# Assigning cluster labels: 20.71% complete
# Assigning cluster labels: 20.80% complete
# Assigning cluster labels: 20.89% complete
# Assigning cluster labels: 20.98% complete
# Assigning cluster labels: 21.07% complete
# Assigning cluster labels: 21.15% complete
# Assigning cluster labels: 21.24% complete
# Assigning cluster labels: 21.33% complete
# Assigning cluster labels: 21.42% complete
# Assigning cluster labels: 21.51% complete
# Assigning cluster labels: 21.59% complete
# Assigning cluster labels: 21.68% complete
# Assigning cluster labels: 21.77% complete
# Assigning cluster labels: 21.86% complete
# Assigning cluster labels: 21.95% complete
# Assigning cluster labels: 22.04% complete
# Assigning cluster labels: 22.12% complete
# Assigning cluster labels: 22.21% complete
# Assigning cluster labels: 22.30% complete
# Assigning cluster labels: 22.39% complete
# Assigning cluster labels: 22.48% complete
# Assigning cluster labels: 22.56% complete
# Assigning cluster labels: 22.65% complete
# Assigning cluster labels: 22.74% complete
# Assigning cluster labels: 22.83% complete
# Assigning cluster labels: 22.92% complete
# Assigning cluster labels: 23.00% complete
# Assigning cluster labels: 23.09% complete
# Assigning cluster labels: 23.18% complete
# Assigning cluster labels: 23.27% complete
# Assigning cluster labels: 23.36% complete
# Assigning cluster labels: 23.45% complete
# Assigning cluster labels: 23.53% complete
# Assigning cluster labels: 23.62% complete
# Assigning cluster labels: 23.71% complete
# Assigning cluster labels: 23.80% complete
# Assigning cluster labels: 23.89% complete
# Assigning cluster labels: 23.97% complete
# Assigning cluster labels: 24.06% complete
# Assigning cluster labels: 24.15% complete
# Assigning cluster labels: 24.24% complete
# Assigning cluster labels: 24.33% complete
# Assigning cluster labels: 24.42% complete
# Assigning cluster labels: 24.50% complete
# Assigning cluster labels: 24.59% complete
# Assigning cluster labels: 24.68% complete
# Assigning cluster labels: 24.77% complete
# Assigning cluster labels: 24.86% complete
# Assigning cluster labels: 24.94% complete
# Assigning cluster labels: 25.03% complete
# Assigning cluster labels: 25.12% complete
# Assigning cluster labels: 25.21% complete
# Assigning cluster labels: 25.30% complete
# Assigning cluster labels: 25.38% complete
# Assigning cluster labels: 25.47% complete
# Assigning cluster labels: 25.56% complete
# Assigning cluster labels: 25.65% complete
# Assigning cluster labels: 25.74% complete
# Assigning cluster labels: 25.83% complete
# Assigning cluster labels: 25.91% complete
# Assigning cluster labels: 26.00% complete
# Assigning cluster labels: 26.09% complete
# Assigning cluster labels: 26.18% complete
# Assigning cluster labels: 26.27% complete
# Assigning cluster labels: 26.35% complete
# Assigning cluster labels: 26.44% complete
# Assigning cluster labels: 26.53% complete
# Assigning cluster labels: 26.62% complete
# Assigning cluster labels: 26.71% complete
# Assigning cluster labels: 26.79% complete
# Assigning cluster labels: 26.88% complete
# Assigning cluster labels: 26.97% complete
# Assigning cluster labels: 27.06% complete
# Assigning cluster labels: 27.15% complete
# Assigning cluster labels: 27.24% complete
# Assigning cluster labels: 27.32% complete
# Assigning cluster labels: 27.41% complete
# Assigning cluster labels: 27.50% complete
# Assigning cluster labels: 27.59% complete
# Assigning cluster labels: 27.68% complete
# Assigning cluster labels: 27.76% complete
# Assigning cluster labels: 27.85% complete
# Assigning cluster labels: 27.94% complete
# Assigning cluster labels: 28.03% complete
# Assigning cluster labels: 28.12% complete
# Assigning cluster labels: 28.21% complete
# Assigning cluster labels: 28.29% complete
# Assigning cluster labels: 28.38% complete
# Assigning cluster labels: 28.47% complete
# Assigning cluster labels: 28.56% complete
# Assigning cluster labels: 28.65% complete
# Assigning cluster labels: 28.73% complete
# Assigning cluster labels: 28.82% complete
# Assigning cluster labels: 28.91% complete
# Assigning cluster labels: 29.00% complete
# Assigning cluster labels: 29.09% complete
# Assigning cluster labels: 29.17% complete
# Assigning cluster labels: 29.26% complete
# Assigning cluster labels: 29.35% complete
# Assigning cluster labels: 29.44% complete
# Assigning cluster labels: 29.53% complete
# Assigning cluster labels: 29.62% complete
# Assigning cluster labels: 29.70% complete
# Assigning cluster labels: 29.79% complete
# Assigning cluster labels: 29.88% complete
# Assigning cluster labels: 29.97% complete
# Assigning cluster labels: 30.06% complete
# Assigning cluster labels: 30.14% complete
# Assigning cluster labels: 30.23% complete
# Assigning cluster labels: 30.32% complete
# Assigning cluster labels: 30.41% complete
# Assigning cluster labels: 30.50% complete
# Assigning cluster labels: 30.58% complete
# Assigning cluster labels: 30.67% complete
# Assigning cluster labels: 30.76% complete
# Assigning cluster labels: 30.85% complete
# Assigning cluster labels: 30.94% complete
# Assigning cluster labels: 31.03% complete
# Assigning cluster labels: 31.11% complete
# Assigning cluster labels: 31.20% complete
# Assigning cluster labels: 31.29% complete
# Assigning cluster labels: 31.38% complete
# Assigning cluster labels: 31.47% complete
# Assigning cluster labels: 31.55% complete
# Assigning cluster labels: 31.64% complete
# Assigning cluster labels: 31.73% complete
# Assigning cluster labels: 31.82% complete
# Assigning cluster labels: 31.91% complete
# Assigning cluster labels: 32.00% complete
# Assigning cluster labels: 32.08% complete
# Assigning cluster labels: 32.17% complete
# Assigning cluster labels: 32.26% complete
# Assigning cluster labels: 32.35% complete
# Assigning cluster labels: 32.44% complete
# Assigning cluster labels: 32.52% complete
# Assigning cluster labels: 32.61% complete
# Assigning cluster labels: 32.70% complete
# Assigning cluster labels: 32.79% complete
# Assigning cluster labels: 32.88% complete
# Assigning cluster labels: 32.96% complete
# Assigning cluster labels: 33.05% complete
# Assigning cluster labels: 33.14% complete
# Assigning cluster labels: 33.23% complete
# Assigning cluster labels: 33.32% complete
# Assigning cluster labels: 33.41% complete
# Assigning cluster labels: 33.49% complete
# Assigning cluster labels: 33.58% complete
# Assigning cluster labels: 33.67% complete
# Assigning cluster labels: 33.76% complete
# Assigning cluster labels: 33.85% complete
# Assigning cluster labels: 33.93% complete
# Assigning cluster labels: 34.02% complete
# Assigning cluster labels: 34.11% complete
# Assigning cluster labels: 34.20% complete
# Assigning cluster labels: 34.29% complete
# Assigning cluster labels: 34.37% complete
# Assigning cluster labels: 34.46% complete
# Assigning cluster labels: 34.55% complete
# Assigning cluster labels: 34.64% complete
# Assigning cluster labels: 34.73% complete
# Assigning cluster labels: 34.82% complete
# Assigning cluster labels: 34.90% complete
# Assigning cluster labels: 34.99% complete
# Assigning cluster labels: 35.08% complete
# Assigning cluster labels: 35.17% complete
# Assigning cluster labels: 35.26% complete
# Assigning cluster labels: 35.34% complete
# Assigning cluster labels: 35.43% complete
# Assigning cluster labels: 35.52% complete
# Assigning cluster labels: 35.61% complete
# Assigning cluster labels: 35.70% complete
# Assigning cluster labels: 35.79% complete
# Assigning cluster labels: 35.87% complete
# Assigning cluster labels: 35.96% complete
# Assigning cluster labels: 36.05% complete
# Assigning cluster labels: 36.14% complete
# Assigning cluster labels: 36.23% complete
# Assigning cluster labels: 36.31% complete
# Assigning cluster labels: 36.40% complete
# Assigning cluster labels: 36.49% complete
# Assigning cluster labels: 36.58% complete
# Assigning cluster labels: 36.67% complete
# Assigning cluster labels: 36.75% complete
# Assigning cluster labels: 36.84% complete
# Assigning cluster labels: 36.93% complete
# Assigning cluster labels: 37.02% complete
# Assigning cluster labels: 37.11% complete
# Assigning cluster labels: 37.20% complete
# Assigning cluster labels: 37.28% complete
# Assigning cluster labels: 37.37% complete
# Assigning cluster labels: 37.46% complete
# Assigning cluster labels: 37.55% complete
# Assigning cluster labels: 37.64% complete
# Assigning cluster labels: 37.72% complete
# Assigning cluster labels: 37.81% complete
# Assigning cluster labels: 37.90% complete
# Assigning cluster labels: 37.99% complete
# Assigning cluster labels: 38.08% complete
# Assigning cluster labels: 38.16% complete
# Assigning cluster labels: 38.25% complete
# Assigning cluster labels: 38.34% complete
# Assigning cluster labels: 38.43% complete
# Assigning cluster labels: 38.52% complete
# Assigning cluster labels: 38.61% complete
# Assigning cluster labels: 38.69% complete
# Assigning cluster labels: 38.78% complete
# Assigning cluster labels: 38.87% complete
# Assigning cluster labels: 38.96% complete
# Assigning cluster labels: 39.05% complete
# Assigning cluster labels: 39.13% complete
# Assigning cluster labels: 39.22% complete
# Assigning cluster labels: 39.31% complete
# Assigning cluster labels: 39.40% complete
# Assigning cluster labels: 39.49% complete
# Assigning cluster labels: 39.58% complete
# Assigning cluster labels: 39.66% complete
# Assigning cluster labels: 39.75% complete
# Assigning cluster labels: 39.84% complete
# Assigning cluster labels: 39.93% complete
# Assigning cluster labels: 40.02% complete
# Assigning cluster labels: 40.10% complete
# Assigning cluster labels: 40.19% complete
# Assigning cluster labels: 40.28% complete
# Assigning cluster labels: 40.37% complete
# Assigning cluster labels: 40.46% complete
# Assigning cluster labels: 40.54% complete
# Assigning cluster labels: 40.63% complete
# Assigning cluster labels: 40.72% complete
# Assigning cluster labels: 40.81% complete
# Assigning cluster labels: 40.90% complete
# Assigning cluster labels: 40.99% complete
# Assigning cluster labels: 41.07% complete
# Assigning cluster labels: 41.16% complete
# Assigning cluster labels: 41.25% complete
# Assigning cluster labels: 41.34% complete
# Assigning cluster labels: 41.43% complete
# Assigning cluster labels: 41.51% complete
# Assigning cluster labels: 41.60% complete
# Assigning cluster labels: 41.69% complete
# Assigning cluster labels: 41.78% complete
# Assigning cluster labels: 41.87% complete
# Assigning cluster labels: 41.96% complete
# Assigning cluster labels: 42.04% complete
# Assigning cluster labels: 42.13% complete
# Assigning cluster labels: 42.22% complete
# Assigning cluster labels: 42.31% complete
# Assigning cluster labels: 42.40% complete
# Assigning cluster labels: 42.48% complete
# Assigning cluster labels: 42.57% complete
# Assigning cluster labels: 42.66% complete
# Assigning cluster labels: 42.75% complete
# Assigning cluster labels: 42.84% complete
# Assigning cluster labels: 42.92% complete
# Assigning cluster labels: 43.01% complete
# Assigning cluster labels: 43.10% complete
# Assigning cluster labels: 43.19% complete
# Assigning cluster labels: 43.28% complete
# Assigning cluster labels: 43.37% complete
# Assigning cluster labels: 43.45% complete
# Assigning cluster labels: 43.54% complete
# Assigning cluster labels: 43.63% complete
# Assigning cluster labels: 43.72% complete
# Assigning cluster labels: 43.81% complete
# Assigning cluster labels: 43.89% complete
# Assigning cluster labels: 43.98% complete
# Assigning cluster labels: 44.07% complete
# Assigning cluster labels: 44.16% complete
# Assigning cluster labels: 44.25% complete
# Assigning cluster labels: 44.33% complete
# Assigning cluster labels: 44.42% complete
# Assigning cluster labels: 44.51% complete
# Assigning cluster labels: 44.60% complete
# Assigning cluster labels: 44.69% complete
# Assigning cluster labels: 44.78% complete
# Assigning cluster labels: 44.86% complete
# Assigning cluster labels: 44.95% complete
# Assigning cluster labels: 45.04% complete
# Assigning cluster labels: 45.13% complete
# Assigning cluster labels: 45.22% complete
# Assigning cluster labels: 45.30% complete
# Assigning cluster labels: 45.39% complete
# Assigning cluster labels: 45.48% complete
# Assigning cluster labels: 45.57% complete
# Assigning cluster labels: 45.66% complete
# Assigning cluster labels: 45.75% complete
# Assigning cluster labels: 45.83% complete
# Assigning cluster labels: 45.92% complete
# Assigning cluster labels: 46.01% complete
# Assigning cluster labels: 46.10% complete
# Assigning cluster labels: 46.19% complete
# Assigning cluster labels: 46.27% complete
# Assigning cluster labels: 46.36% complete
# Assigning cluster labels: 46.45% complete
# Assigning cluster labels: 46.54% complete
# Assigning cluster labels: 46.63% complete
# Assigning cluster labels: 46.71% complete
# Assigning cluster labels: 46.80% complete
# Assigning cluster labels: 46.89% complete
# Assigning cluster labels: 46.98% complete
# Assigning cluster labels: 47.07% complete
# Assigning cluster labels: 47.16% complete
# Assigning cluster labels: 47.24% complete
# Assigning cluster labels: 47.33% complete
# Assigning cluster labels: 47.42% complete
# Assigning cluster labels: 47.51% complete
# Assigning cluster labels: 47.60% complete
# Assigning cluster labels: 47.68% complete
# Assigning cluster labels: 47.77% complete
# Assigning cluster labels: 47.86% complete
# Assigning cluster labels: 47.95% complete
# Assigning cluster labels: 48.04% complete
# Assigning cluster labels: 48.12% complete
# Assigning cluster labels: 48.21% complete
# Assigning cluster labels: 48.30% complete
# Assigning cluster labels: 48.39% complete
# Assigning cluster labels: 48.48% complete
# Assigning cluster labels: 48.57% complete
# Assigning cluster labels: 48.65% complete
# Assigning cluster labels: 48.74% complete
# Assigning cluster labels: 48.83% complete
# Assigning cluster labels: 48.92% complete
# Assigning cluster labels: 49.01% complete
# Assigning cluster labels: 49.09% complete
# Assigning cluster labels: 49.18% complete
# Assigning cluster labels: 49.27% complete
# Assigning cluster labels: 49.36% complete
# Assigning cluster labels: 49.45% complete
# Assigning cluster labels: 49.54% complete
# Assigning cluster labels: 49.62% complete
# Assigning cluster labels: 49.71% complete
# Assigning cluster labels: 49.80% complete
# Assigning cluster labels: 49.89% complete
# Assigning cluster labels: 49.98% complete
# Assigning cluster labels: 50.06% complete
# Assigning cluster labels: 50.15% complete
# Assigning cluster labels: 50.24% complete
# Assigning cluster labels: 50.33% complete
# Assigning cluster labels: 50.42% complete
# Assigning cluster labels: 50.50% complete
# Assigning cluster labels: 50.59% complete
# Assigning cluster labels: 50.68% complete
# Assigning cluster labels: 50.77% complete
# Assigning cluster labels: 50.86% complete
# Assigning cluster labels: 50.95% complete
# Assigning cluster labels: 51.03% complete
# Assigning cluster labels: 51.12% complete
# Assigning cluster labels: 51.21% complete
# Assigning cluster labels: 51.30% complete
# Assigning cluster labels: 51.39% complete
# Assigning cluster labels: 51.47% complete
# Assigning cluster labels: 51.56% complete
# Assigning cluster labels: 51.65% complete
# Assigning cluster labels: 51.74% complete
# Assigning cluster labels: 51.83% complete
# Assigning cluster labels: 51.91% complete
# Assigning cluster labels: 52.00% complete
# Assigning cluster labels: 52.09% complete
# Assigning cluster labels: 52.18% complete
# Assigning cluster labels: 52.27% complete
# Assigning cluster labels: 52.36% complete
# Assigning cluster labels: 52.44% complete
# Assigning cluster labels: 52.53% complete
# Assigning cluster labels: 52.62% complete
# Assigning cluster labels: 52.71% complete
# Assigning cluster labels: 52.80% complete
# Assigning cluster labels: 52.88% complete
# Assigning cluster labels: 52.97% complete
# Assigning cluster labels: 53.06% complete
# Assigning cluster labels: 53.15% complete
# Assigning cluster labels: 53.24% complete
# Assigning cluster labels: 53.33% complete
# Assigning cluster labels: 53.41% complete
# Assigning cluster labels: 53.50% complete
# Assigning cluster labels: 53.59% complete
# Assigning cluster labels: 53.68% complete
# Assigning cluster labels: 53.77% complete
# Assigning cluster labels: 53.85% complete
# Assigning cluster labels: 53.94% complete
# Assigning cluster labels: 54.03% complete
# Assigning cluster labels: 54.12% complete
# Assigning cluster labels: 54.21% complete
# Assigning cluster labels: 54.29% complete
# Assigning cluster labels: 54.38% complete
# Assigning cluster labels: 54.47% complete
# Assigning cluster labels: 54.56% complete
# Assigning cluster labels: 54.65% complete
# Assigning cluster labels: 54.74% complete
# Assigning cluster labels: 54.82% complete
# Assigning cluster labels: 54.91% complete
# Assigning cluster labels: 55.00% complete
# Assigning cluster labels: 55.09% complete
# Assigning cluster labels: 55.18% complete
# Assigning cluster labels: 55.26% complete
# Assigning cluster labels: 55.35% complete
# Assigning cluster labels: 55.44% complete
# Assigning cluster labels: 55.53% complete
# Assigning cluster labels: 55.62% complete
# Assigning cluster labels: 55.71% complete
# Assigning cluster labels: 55.79% complete
# Assigning cluster labels: 55.88% complete
# Assigning cluster labels: 55.97% complete
# Assigning cluster labels: 56.06% complete
# Assigning cluster labels: 56.15% complete
# Assigning cluster labels: 56.23% complete
# Assigning cluster labels: 56.32% complete
# Assigning cluster labels: 56.41% complete
# Assigning cluster labels: 56.50% complete
# Assigning cluster labels: 56.59% complete
# Assigning cluster labels: 56.67% complete
# Assigning cluster labels: 56.76% complete
# Assigning cluster labels: 56.85% complete
# Assigning cluster labels: 56.94% complete
# Assigning cluster labels: 57.03% complete
# Assigning cluster labels: 57.12% complete
# Assigning cluster labels: 57.20% complete
# Assigning cluster labels: 57.29% complete
# Assigning cluster labels: 57.38% complete
# Assigning cluster labels: 57.47% complete
# Assigning cluster labels: 57.56% complete
# Assigning cluster labels: 57.64% complete
# Assigning cluster labels: 57.73% complete
# Assigning cluster labels: 57.82% complete
# Assigning cluster labels: 57.91% complete
# Assigning cluster labels: 58.00% complete
# Assigning cluster labels: 58.08% complete
# Assigning cluster labels: 58.17% complete
# Assigning cluster labels: 58.26% complete
# Assigning cluster labels: 58.35% complete
# Assigning cluster labels: 58.44% complete
# Assigning cluster labels: 58.53% complete
# Assigning cluster labels: 58.61% complete
# Assigning cluster labels: 58.70% complete
# Assigning cluster labels: 58.79% complete
# Assigning cluster labels: 58.88% complete
# Assigning cluster labels: 58.97% complete
# Assigning cluster labels: 59.05% complete
# Assigning cluster labels: 59.14% complete
# Assigning cluster labels: 59.23% complete
# Assigning cluster labels: 59.32% complete
# Assigning cluster labels: 59.41% complete
# Assigning cluster labels: 59.50% complete
# Assigning cluster labels: 59.58% complete
# Assigning cluster labels: 59.67% complete
# Assigning cluster labels: 59.76% complete
# Assigning cluster labels: 59.85% complete
# Assigning cluster labels: 59.94% complete
# Assigning cluster labels: 60.02% complete
# Assigning cluster labels: 60.11% complete
# Assigning cluster labels: 60.20% complete
# Assigning cluster labels: 60.29% complete
# Assigning cluster labels: 60.38% complete
# Assigning cluster labels: 60.46% complete
# Assigning cluster labels: 60.55% complete
# Assigning cluster labels: 60.64% complete
# Assigning cluster labels: 60.73% complete
# Assigning cluster labels: 60.82% complete
# Assigning cluster labels: 60.91% complete
# Assigning cluster labels: 60.99% complete
# Assigning cluster labels: 61.08% complete
# Assigning cluster labels: 61.17% complete
# Assigning cluster labels: 61.26% complete
# Assigning cluster labels: 61.35% complete
# Assigning cluster labels: 61.43% complete
# Assigning cluster labels: 61.52% complete
# Assigning cluster labels: 61.61% complete
# Assigning cluster labels: 61.70% complete
# Assigning cluster labels: 61.79% complete
# Assigning cluster labels: 61.87% complete
# Assigning cluster labels: 61.96% complete
# Assigning cluster labels: 62.05% complete
# Assigning cluster labels: 62.14% complete
# Assigning cluster labels: 62.23% complete
# Assigning cluster labels: 62.32% complete
# Assigning cluster labels: 62.40% complete
# Assigning cluster labels: 62.49% complete
# Assigning cluster labels: 62.58% complete
# Assigning cluster labels: 62.67% complete
# Assigning cluster labels: 62.76% complete
# Assigning cluster labels: 62.84% complete
# Assigning cluster labels: 62.93% complete
# Assigning cluster labels: 63.02% complete
# Assigning cluster labels: 63.11% complete
# Assigning cluster labels: 63.20% complete
# Assigning cluster labels: 63.29% complete
# Assigning cluster labels: 63.37% complete
# Assigning cluster labels: 63.46% complete
# Assigning cluster labels: 63.55% complete
# Assigning cluster labels: 63.64% complete
# Assigning cluster labels: 63.73% complete
# Assigning cluster labels: 63.81% complete
# Assigning cluster labels: 63.90% complete
# Assigning cluster labels: 63.99% complete
# Assigning cluster labels: 64.08% complete
# Assigning cluster labels: 64.17% complete
# Assigning cluster labels: 64.25% complete
# Assigning cluster labels: 64.34% complete
# Assigning cluster labels: 64.43% complete
# Assigning cluster labels: 64.52% complete
# Assigning cluster labels: 64.61% complete
# Assigning cluster labels: 64.70% complete
# Assigning cluster labels: 64.78% complete
# Assigning cluster labels: 64.87% complete
# Assigning cluster labels: 64.96% complete
# Assigning cluster labels: 65.05% complete
# Assigning cluster labels: 65.14% complete
# Assigning cluster labels: 65.22% complete
# Assigning cluster labels: 65.31% complete
# Assigning cluster labels: 65.40% complete
# Assigning cluster labels: 65.49% complete
# Assigning cluster labels: 65.58% complete
# Assigning cluster labels: 65.66% complete
# Assigning cluster labels: 65.75% complete
# Assigning cluster labels: 65.84% complete
# Assigning cluster labels: 65.93% complete
# Assigning cluster labels: 66.02% complete
# Assigning cluster labels: 66.11% complete
# Assigning cluster labels: 66.19% complete
# Assigning cluster labels: 66.28% complete
# Assigning cluster labels: 66.37% complete
# Assigning cluster labels: 66.46% complete
# Assigning cluster labels: 66.55% complete
# Assigning cluster labels: 66.63% complete
# Assigning cluster labels: 66.72% complete
# Assigning cluster labels: 66.81% complete
# Assigning cluster labels: 66.90% complete
# Assigning cluster labels: 66.99% complete
# Assigning cluster labels: 67.08% complete
# Assigning cluster labels: 67.16% complete
# Assigning cluster labels: 67.25% complete
# Assigning cluster labels: 67.34% complete
# Assigning cluster labels: 67.43% complete
# Assigning cluster labels: 67.52% complete
# Assigning cluster labels: 67.60% complete
# Assigning cluster labels: 67.69% complete
# Assigning cluster labels: 67.78% complete
# Assigning cluster labels: 67.87% complete
# Assigning cluster labels: 67.96% complete
# Assigning cluster labels: 68.04% complete
# Assigning cluster labels: 68.13% complete
# Assigning cluster labels: 68.22% complete
# Assigning cluster labels: 68.31% complete
# Assigning cluster labels: 68.40% complete
# Assigning cluster labels: 68.49% complete
# Assigning cluster labels: 68.57% complete
# Assigning cluster labels: 68.66% complete
# Assigning cluster labels: 68.75% complete
# Assigning cluster labels: 68.84% complete
# Assigning cluster labels: 68.93% complete
# Assigning cluster labels: 69.01% complete
# Assigning cluster labels: 69.10% complete
# Assigning cluster labels: 69.19% complete
# Assigning cluster labels: 69.28% complete
# Assigning cluster labels: 69.37% complete
# Assigning cluster labels: 69.45% complete
# Assigning cluster labels: 69.54% complete
# Assigning cluster labels: 69.63% complete
# Assigning cluster labels: 69.72% complete
# Assigning cluster labels: 69.81% complete
# Assigning cluster labels: 69.90% complete
# Assigning cluster labels: 69.98% complete
# Assigning cluster labels: 70.07% complete
# Assigning cluster labels: 70.16% complete
# Assigning cluster labels: 70.25% complete
# Assigning cluster labels: 70.34% complete
# Assigning cluster labels: 70.42% complete
# Assigning cluster labels: 70.51% complete
# Assigning cluster labels: 70.60% complete
# Assigning cluster labels: 70.69% complete
# Assigning cluster labels: 70.78% complete
# Assigning cluster labels: 70.87% complete
# Assigning cluster labels: 70.95% complete
# Assigning cluster labels: 71.04% complete
# Assigning cluster labels: 71.13% complete
# Assigning cluster labels: 71.22% complete
# Assigning cluster labels: 71.31% complete
# Assigning cluster labels: 71.39% complete
# Assigning cluster labels: 71.48% complete
# Assigning cluster labels: 71.57% complete
# Assigning cluster labels: 71.66% complete
# Assigning cluster labels: 71.75% complete
# Assigning cluster labels: 71.83% complete
# Assigning cluster labels: 71.92% complete
# Assigning cluster labels: 72.01% complete
# Assigning cluster labels: 72.10% complete
# Assigning cluster labels: 72.19% complete
# Assigning cluster labels: 72.28% complete
# Assigning cluster labels: 72.36% complete
# Assigning cluster labels: 72.45% complete
# Assigning cluster labels: 72.54% complete
# Assigning cluster labels: 72.63% complete
# Assigning cluster labels: 72.72% complete
# Assigning cluster labels: 72.80% complete
# Assigning cluster labels: 72.89% complete
# Assigning cluster labels: 72.98% complete
# Assigning cluster labels: 73.07% complete
# Assigning cluster labels: 73.16% complete
# Assigning cluster labels: 73.25% complete
# Assigning cluster labels: 73.33% complete
# Assigning cluster labels: 73.42% complete
# Assigning cluster labels: 73.51% complete
# Assigning cluster labels: 73.60% complete
# Assigning cluster labels: 73.69% complete
# Assigning cluster labels: 73.77% complete
# Assigning cluster labels: 73.86% complete
# Assigning cluster labels: 73.95% complete
# Assigning cluster labels: 74.04% complete
# Assigning cluster labels: 74.13% complete
# Assigning cluster labels: 74.21% complete
# Assigning cluster labels: 74.30% complete
# Assigning cluster labels: 74.39% complete
# Assigning cluster labels: 74.48% complete
# Assigning cluster labels: 74.57% complete
# Assigning cluster labels: 74.66% complete
# Assigning cluster labels: 74.74% complete
# Assigning cluster labels: 74.83% complete
# Assigning cluster labels: 74.92% complete
# Assigning cluster labels: 75.01% complete
# Assigning cluster labels: 75.10% complete
# Assigning cluster labels: 75.18% complete
# Assigning cluster labels: 75.27% complete
# Assigning cluster labels: 75.36% complete
# Assigning cluster labels: 75.45% complete
# Assigning cluster labels: 75.54% complete
# Assigning cluster labels: 75.62% complete
# Assigning cluster labels: 75.71% complete
# Assigning cluster labels: 75.80% complete
# Assigning cluster labels: 75.89% complete
# Assigning cluster labels: 75.98% complete
# Assigning cluster labels: 76.07% complete
# Assigning cluster labels: 76.15% complete
# Assigning cluster labels: 76.24% complete
# Assigning cluster labels: 76.33% complete
# Assigning cluster labels: 76.42% complete
# Assigning cluster labels: 76.51% complete
# Assigning cluster labels: 76.59% complete
# Assigning cluster labels: 76.68% complete
# Assigning cluster labels: 76.77% complete
# Assigning cluster labels: 76.86% complete
# Assigning cluster labels: 76.95% complete
# Assigning cluster labels: 77.04% complete
# Assigning cluster labels: 77.12% complete
# Assigning cluster labels: 77.21% complete
# Assigning cluster labels: 77.30% complete
# Assigning cluster labels: 77.39% complete
# Assigning cluster labels: 77.48% complete
# Assigning cluster labels: 77.56% complete
# Assigning cluster labels: 77.65% complete
# Assigning cluster labels: 77.74% complete
# Assigning cluster labels: 77.83% complete
# Assigning cluster labels: 77.92% complete
# Assigning cluster labels: 78.00% complete
# Assigning cluster labels: 78.09% complete
# Assigning cluster labels: 78.18% complete
# Assigning cluster labels: 78.27% complete
# Assigning cluster labels: 78.36% complete
# Assigning cluster labels: 78.45% complete
# Assigning cluster labels: 78.53% complete
# Assigning cluster labels: 78.62% complete
# Assigning cluster labels: 78.71% complete
# Assigning cluster labels: 78.80% complete
# Assigning cluster labels: 78.89% complete
# Assigning cluster labels: 78.97% complete
# Assigning cluster labels: 79.06% complete
# Assigning cluster labels: 79.15% complete
# Assigning cluster labels: 79.24% complete
# Assigning cluster labels: 79.33% complete
# Assigning cluster labels: 79.41% complete
# Assigning cluster labels: 79.50% complete
# Assigning cluster labels: 79.59% complete
# Assigning cluster labels: 79.68% complete
# Assigning cluster labels: 79.77% complete
# Assigning cluster labels: 79.86% complete
# Assigning cluster labels: 79.94% complete
# Assigning cluster labels: 80.03% complete
# Assigning cluster labels: 80.12% complete
# Assigning cluster labels: 80.21% complete
# Assigning cluster labels: 80.30% complete
# Assigning cluster labels: 80.38% complete
# Assigning cluster labels: 80.47% complete
# Assigning cluster labels: 80.56% complete
# Assigning cluster labels: 80.65% complete
# Assigning cluster labels: 80.74% complete
# Assigning cluster labels: 80.83% complete
# Assigning cluster labels: 80.91% complete
# Assigning cluster labels: 81.00% complete
# Assigning cluster labels: 81.09% complete
# Assigning cluster labels: 81.18% complete
# Assigning cluster labels: 81.27% complete
# Assigning cluster labels: 81.35% complete
# Assigning cluster labels: 81.44% complete
# Assigning cluster labels: 81.53% complete
# Assigning cluster labels: 81.62% complete
# Assigning cluster labels: 81.71% complete
# Assigning cluster labels: 81.79% complete
# Assigning cluster labels: 81.88% complete
# Assigning cluster labels: 81.97% complete
# Assigning cluster labels: 82.06% complete
# Assigning cluster labels: 82.15% complete
# Assigning cluster labels: 82.24% complete
# Assigning cluster labels: 82.32% complete
# Assigning cluster labels: 82.41% complete
# Assigning cluster labels: 82.50% complete
# Assigning cluster labels: 82.59% complete
# Assigning cluster labels: 82.68% complete
# Assigning cluster labels: 82.76% complete
# Assigning cluster labels: 82.85% complete
# Assigning cluster labels: 82.94% complete
# Assigning cluster labels: 83.03% complete
# Assigning cluster labels: 83.12% complete
# Assigning cluster labels: 83.20% complete
# Assigning cluster labels: 83.29% complete
# Assigning cluster labels: 83.38% complete
# Assigning cluster labels: 83.47% complete
# Assigning cluster labels: 83.56% complete
# Assigning cluster labels: 83.65% complete
# Assigning cluster labels: 83.73% complete
# Assigning cluster labels: 83.82% complete
# Assigning cluster labels: 83.91% complete
# Assigning cluster labels: 84.00% complete
# Assigning cluster labels: 84.09% complete
# Assigning cluster labels: 84.17% complete
# Assigning cluster labels: 84.26% complete
# Assigning cluster labels: 84.35% complete
# Assigning cluster labels: 84.44% complete
# Assigning cluster labels: 84.53% complete
# Assigning cluster labels: 84.62% complete
# Assigning cluster labels: 84.70% complete
# Assigning cluster labels: 84.79% complete
# Assigning cluster labels: 84.88% complete
# Assigning cluster labels: 84.97% complete
# Assigning cluster labels: 85.06% complete
# Assigning cluster labels: 85.14% complete
# Assigning cluster labels: 85.23% complete
# Assigning cluster labels: 85.32% complete
# Assigning cluster labels: 85.41% complete
# Assigning cluster labels: 85.50% complete
# Assigning cluster labels: 85.58% complete
# Assigning cluster labels: 85.67% complete
# Assigning cluster labels: 85.76% complete
# Assigning cluster labels: 85.85% complete
# Assigning cluster labels: 85.94% complete
# Assigning cluster labels: 86.03% complete
# Assigning cluster labels: 86.11% complete
# Assigning cluster labels: 86.20% complete
# Assigning cluster labels: 86.29% complete
# Assigning cluster labels: 86.38% complete
# Assigning cluster labels: 86.47% complete
# Assigning cluster labels: 86.55% complete
# Assigning cluster labels: 86.64% complete
# Assigning cluster labels: 86.73% complete
# Assigning cluster labels: 86.82% complete
# Assigning cluster labels: 86.91% complete
# Assigning cluster labels: 86.99% complete
# Assigning cluster labels: 87.08% complete
# Assigning cluster labels: 87.17% complete
# Assigning cluster labels: 87.26% complete
# Assigning cluster labels: 87.35% complete
# Assigning cluster labels: 87.44% complete
# Assigning cluster labels: 87.52% complete
# Assigning cluster labels: 87.61% complete
# Assigning cluster labels: 87.70% complete
# Assigning cluster labels: 87.79% complete
# Assigning cluster labels: 87.88% complete
# Assigning cluster labels: 87.96% complete
# Assigning cluster labels: 88.05% complete
# Assigning cluster labels: 88.14% complete
# Assigning cluster labels: 88.23% complete
# Assigning cluster labels: 88.32% complete
# Assigning cluster labels: 88.41% complete
# Assigning cluster labels: 88.49% complete
# Assigning cluster labels: 88.58% complete
# Assigning cluster labels: 88.67% complete
# Assigning cluster labels: 88.76% complete
# Assigning cluster labels: 88.85% complete
# Assigning cluster labels: 88.93% complete
# Assigning cluster labels: 89.02% complete
# Assigning cluster labels: 89.11% complete
# Assigning cluster labels: 89.20% complete
# Assigning cluster labels: 89.29% complete
# Assigning cluster labels: 89.37% complete
# Assigning cluster labels: 89.46% complete
# Assigning cluster labels: 89.55% complete
# Assigning cluster labels: 89.64% complete
# Assigning cluster labels: 89.73% complete
# Assigning cluster labels: 89.82% complete
# Assigning cluster labels: 89.90% complete
# Assigning cluster labels: 89.99% complete
# Assigning cluster labels: 90.08% complete
# Assigning cluster labels: 90.17% complete
# Assigning cluster labels: 90.26% complete
# Assigning cluster labels: 90.34% complete
# Assigning cluster labels: 90.43% complete
# Assigning cluster labels: 90.52% complete
# Assigning cluster labels: 90.61% complete
# Assigning cluster labels: 90.70% complete
# Assigning cluster labels: 90.79% complete
# Assigning cluster labels: 90.87% complete
# Assigning cluster labels: 90.96% complete
# Assigning cluster labels: 91.05% complete
# Assigning cluster labels: 91.14% complete
# Assigning cluster labels: 91.23% complete
# Assigning cluster labels: 91.31% complete
# Assigning cluster labels: 91.40% complete
# Assigning cluster labels: 91.49% complete
# Assigning cluster labels: 91.58% complete
# Assigning cluster labels: 91.67% complete
# Assigning cluster labels: 91.75% complete
# Assigning cluster labels: 91.84% complete
# Assigning cluster labels: 91.93% complete
# Assigning cluster labels: 92.02% complete
# Assigning cluster labels: 92.11% complete
# Assigning cluster labels: 92.20% complete
# Assigning cluster labels: 92.28% complete
# Assigning cluster labels: 92.37% complete
# Assigning cluster labels: 92.46% complete
# Assigning cluster labels: 92.55% complete
# Assigning cluster labels: 92.64% complete
# Assigning cluster labels: 92.72% complete
# Assigning cluster labels: 92.81% complete
# Assigning cluster labels: 92.90% complete
# Assigning cluster labels: 92.99% complete
# Assigning cluster labels: 93.08% complete
# Assigning cluster labels: 93.16% complete
# Assigning cluster labels: 93.25% complete
# Assigning cluster labels: 93.34% complete
# Assigning cluster labels: 93.43% complete
# Assigning cluster labels: 93.52% complete
# Assigning cluster labels: 93.61% complete
# Assigning cluster labels: 93.69% complete
# Assigning cluster labels: 93.78% complete
# Assigning cluster labels: 93.87% complete
# Assigning cluster labels: 93.96% complete
# Assigning cluster labels: 94.05% complete
# Assigning cluster labels: 94.13% complete
# Assigning cluster labels: 94.22% complete
# Assigning cluster labels: 94.31% complete
# Assigning cluster labels: 94.40% complete
# Assigning cluster labels: 94.49% complete
# Assigning cluster labels: 94.58% complete
# Assigning cluster labels: 94.66% complete
# Assigning cluster labels: 94.75% complete
# Assigning cluster labels: 94.84% complete
# Assigning cluster labels: 94.93% complete
# Assigning cluster labels: 95.02% complete
# Assigning cluster labels: 95.10% complete
# Assigning cluster labels: 95.19% complete
# Assigning cluster labels: 95.28% complete
# Assigning cluster labels: 95.37% complete
# Assigning cluster labels: 95.46% complete
# Assigning cluster labels: 95.54% complete
# Assigning cluster labels: 95.63% complete
# Assigning cluster labels: 95.72% complete
# Assigning cluster labels: 95.81% complete
# Assigning cluster labels: 95.90% complete
# Assigning cluster labels: 95.99% complete
# Assigning cluster labels: 96.07% complete
# Assigning cluster labels: 96.16% complete
# Assigning cluster labels: 96.25% complete
# Assigning cluster labels: 96.34% complete
# Assigning cluster labels: 96.43% complete
# Assigning cluster labels: 96.51% complete
# Assigning cluster labels: 96.60% complete
# Assigning cluster labels: 96.69% complete
# Assigning cluster labels: 96.78% complete
# Assigning cluster labels: 96.87% complete
# Assigning cluster labels: 96.95% complete
# Assigning cluster labels: 97.04% complete
# Assigning cluster labels: 97.13% complete
# Assigning cluster labels: 97.22% complete
# Assigning cluster labels: 97.31% complete
# Assigning cluster labels: 97.40% complete
# Assigning cluster labels: 97.48% complete
# Assigning cluster labels: 97.57% complete
# Assigning cluster labels: 97.66% complete
# Assigning cluster labels: 97.75% complete
# Assigning cluster labels: 97.84% complete
# Assigning cluster labels: 97.92% complete
# Assigning cluster labels: 98.01% complete
# Assigning cluster labels: 98.10% complete
# Assigning cluster labels: 98.19% complete
# Assigning cluster labels: 98.28% complete
# Assigning cluster labels: 98.37% complete
# Assigning cluster labels: 98.45% complete
# Assigning cluster labels: 98.54% complete
# Assigning cluster labels: 98.63% complete
# Assigning cluster labels: 98.72% complete
# Assigning cluster labels: 98.81% complete
# Assigning cluster labels: 98.89% complete
# Assigning cluster labels: 98.98% complete
# Assigning cluster labels: 99.07% complete
# Assigning cluster labels: 99.16% complete
# Assigning cluster labels: 99.25% complete
# Assigning cluster labels: 99.33% complete
# Assigning cluster labels: 99.42% complete
# Assigning cluster labels: 99.51% complete
# Assigning cluster labels: 99.60% complete
# Assigning cluster labels: 99.69% complete
# Assigning cluster labels: 99.78% complete
# Assigning cluster labels: 99.86% complete
# Assigning cluster labels: 99.95% complete
# Assigning cluster labels: 100.00% complete

# %%
# Convert labels to binary (assuming 0 for non-DDoS and 1 for DDoS)
y_binary = np.where(y > 0, 1, 0)
# print(y_binary)
# print(cluster_labels)
# Convert cluster labels to binary
cluster_labels_binary = np.where(np.array(cluster_labels) > 0, 1, 0)

# %%
# Evaluate accuracy
accuracy = accuracy_score(y_binary, cluster_labels_binary)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8621953412284011

# %%
# # Evaluate accuracy
# accuracy = accuracy_score(y, cluster_labels)
# print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Evaluate accuracy
# ----> 2 accuracy = accuracy_score(y, cluster_labels)
#       3 print("Accuracy:", accuracy)
#
# File ~\Envs\msc\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\Envs\msc\lib\site-packages\sklearn\metrics\_classification.py:213, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     147 """Accuracy classification score.
#     148
#     149 In multilabel classification, this function computes subset accuracy:
#    (...)
#     209 0.5
#     210 """
#     212 # Compute accuracy for each possible representation
# --> 213 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     214 check_consistent_length(y_true, y_pred, sample_weight)
#     215 if y_type.startswith("multilabel"):
#
# File ~\Envs\msc\lib\site-packages\sklearn\metrics\_classification.py:94, in _check_targets(y_true, y_pred)
#      91     y_type = {"multiclass"}
#      93 if len(y_type) > 1:
# ---> 94     raise ValueError(
#      95         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      96             type_true, type_pred
#      97         )
#      98     )
#     100 # We can't have more than one value on y_type => The set is no more needed
#     101 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
